# %%
#Bivariate Association between Numeric Variables of House Prediction Dataset
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"E:\DYPIU\SEM 5\Principle Of DS\LABS\kc_house_data.csv"
df  = pd.read_csv(path)
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
#descibe data
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# checking for null values 
print(f"Null value count in dataset: {df.isna().sum().sum()}")
# Out:
# Null value count in dataset: 2

# %%
# Getting Unique vlaues from the columns

def unique_val(df):
    col_list = list(df.columns)
    for i in col_list:
        print(f"Unique values in column {i} are: {df[i].nunique()}")
        
unique_val(df)
# Out:
# Unique values in column id are: 21436
# Unique values in column date are: 372
# Unique values in column price are: 4028
# Unique values in column bedrooms are: 13
# Unique values in column bathrooms are: 30
# Unique values in column sqft_living are: 1038
# Unique values in column sqft_lot are: 9782
# Unique values in column floors are: 6
# Unique values in column waterfront are: 2
# Unique values in column view are: 5
# Unique values in column condition are: 5
# Unique values in column grade are: 12
# Unique values in column sqft_above are: 946
# Unique values in column sqft_basement are: 306
# Unique values in column yr_built are: 116
# Unique values in column yr_renovated are: 70
# Unique values in column zipcode are: 70
# Unique values in column lat are: 5034
# Unique values in column long are: 752
# Unique values in column sqft_living15 are: 777
# Unique values in column sqft_lot15 are: 8689

# %%
# drop the id column

df = df.drop(labels=['id'],axis=1)
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7      1180.0              0
# 1     2.0           0     0          3      7      2170.0            400
# 2     1.0           0     0          3      6       770.0              0
# 3     1.0           0     0          5      7      1050.0            910
# 4     1.0           0     0          3      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# User-defined function for covariance

def get_covariance(dataframe):
  n = dataframe.shape[0]
  col_set = set(dataframe.columns)
  index_col = 'Columns'
  cov_matrix = pd.DataFrame(columns=[index_col]+list(col_set), index=[i for i in range(0,len(col_set))])
  i = 0
  for x in list(col_set):
    cov_matrix.loc[i,index_col] = x
    x_mean = dataframe[x].mean()
    for y in list(col_set):
      y_mean = dataframe[y].mean()
      x_values = dataframe[x].values.tolist()
      y_values = dataframe[y].values.tolist()
      prod = 0
      for xi, yi in zip(x_values, y_values):
        prod += (xi-x_mean)*(yi-y_mean)
      cov_x_y = prod/n
      cov_x_y = "{:.6e}".format(cov_x_y)
      cov_matrix.loc[i,y] = cov_x_y
    i += 1
  cov_matrix.set_index(index_col,inplace=True)
  return cov_matrix 

covar_dataf = get_covariance(df)
covar_dataf

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1a6fe1782b2f> in <module>
# ----> 1 sns.pairplot(df)
#
# NameError: name 'sns' is not defined

# %%
# correlation user-defined function

def get_correlation(dataframe):
  n = dataframe.shape[0]
  col_set = set(dataframe.columns)
  index_col = 'Columns'
  corr_matrix = pd.DataFrame(columns=[index_col]+list(col_set), index=[i for i in range(0,len(col_set))])
  i = 0
  for x in list(col_set):
    corr_matrix.loc[i,index_col] = x
    x_mean = dataframe[x].mean()
    x_stdv = dataframe[x].std()
    for y in list(col_set):
      y_mean = dataframe[y].mean()
      y_stdv = dataframe[y].std()
      x_values = dataframe[x].values.tolist()
      y_values = dataframe[y].values.tolist()
      prod = 0
      for xi, yi in zip(x_values, y_values):
        prod += (xi-x_mean)*(yi-y_mean)
      cov_x_y = prod/n
      # Pearson's correlation coefficient = covariance(X, Y) / (stdv(X) * stdv(Y))
      corr_x_y = cov_x_y/(x_stdv*y_stdv)

      corr_matrix.loc[i,y] = corr_x_y

    i += 1

  corr_matrix.set_index(index_col,inplace=True)

  return corr_matrix
